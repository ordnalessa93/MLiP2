# %%
import os
import pandas as pd

# Modify the test directory where you put your test images
img_names = [x[:-4] for x in os.listdir('/home/pabloleo96/MLiP2/data/full_data/test')]
# This is the submission csv file
sub = pd.read_csv('submit.csv')

# %%
print (len(img_names))
# Out:
# 1917

# %%
correct_idx = []
print('Total test instance for submission: %d' % len(sub))
for i in range(len(sub)):
    # The correct flag indicates whether this row is correct, if set to False,
    # this row will simply be ignored from the modified submission
    correct_flag = True

    # check whether ImageId is correct
    img_n = sub.loc[i]['ImageId']
    if img_n not in img_names:
        print('Wrong im id : %s' % sub.loc[i]["ImageId"])
        correct_flag = False

    # check LabelIs is within the corpus
    label = sub.loc[i]["LabelId"]
    if label not in [33, 34, 35, 36, 38, 39, 40]:
        print("Wrong label for: %s" % sub.loc[i]["ImageId"])
        correct_flag = False

    # check your confidence is within the right range
    conf = sub.loc[i]['Confidence']
    if conf <= 0 or conf > 1:
        print("wrong confidence for: %s with conf: %.3f" % (sub.loc[i]["ImageId"], sub.loc[i]["Confidence"]))
        correct_flag = False

    # Check your pixel count is within the right range
    pc = sub.loc[i]['PixelCount']
    if pc <= 0 or pc >= 2710 * 3384:
        print("Wrong PC for: %s" % sub.loc[i]["ImageId"])
        correct_flag = False

    rle = sub.loc[i]['EncodedPixels']

    # This is the part where all my mistakes are made!!!! It could be the RLE encoding I used
    if rle[-1] != '|':
        print("Wrong RLE ending for: %s, with conf: %3.f, pixelCount: %d, last EP: %s" %
              (sub.loc[i]["ImageId"], sub.loc[i]['Confidence'], sub.loc[i]['PixelCount'], sub.loc[i]['EncodedPixels'][-10:]))
        correct_flag = False

    rle_pc = 0
    rle_split = rle.split('|')
    start_prev = -1
    for p in range(len(rle_split) - 1):
        start = int(rle_split[p].split(' ')[0])
        length = int(rle_split[p].split(' ')[1])
        if start <= start_prev:
            print("Wrong encoding for: %s" % sub.loc[i]["ImageId"])
            correct_flag = False

        start_prev = start + length

        if start < 0:
            print("Wrong start for: %s" % sub.loc[i]["ImageId"])
            correct_flag = False

        if start_prev >= 2710 * 3384:
            print("Wrong start_prev for: %s" % sub.loc[i]["ImageId"])
            correct_flag = False

        rle_pc += length

    if correct_flag:
        correct_idx.append(i)
    
    if i % 1000 == 0:
        print(i)
    if rle_pc != pc:
        print("Wrong: %d" % i)

print("here")
sub_csv_new = sub.loc[correct_idx]
sub_csv_new.to_csv('correct_submission_test.csv', header=True, index=False)
# Out:
# Total test instance for submission: 69907
# 0
# 1000
# 2000
# Wrong encoding for: 08b9b7a736a725ebb436d1022977bc31
# Wrong start for: 08b9b7a736a725ebb436d1022977bc31
# Wrong encoding for: 08bef744e3a8c9d59fcc2bb6ea11fe1d
# Wrong start for: 08bef744e3a8c9d59fcc2bb6ea11fe1d
# 3000
# Wrong encoding for: 09626b0ec112c03d68e5b0039a3466f9
# Wrong start for: 09626b0ec112c03d68e5b0039a3466f9
# Wrong encoding for: 0b2180badeb7a34a20cc8df145b071d1
# Wrong start for: 0b2180badeb7a34a20cc8df145b071d1
# 4000
# 5000
# Wrong encoding for: 10ecc571e9fe28465ecd2afa6e54630b
# Wrong start for: 10ecc571e9fe28465ecd2afa6e54630b
# 6000
# Wrong encoding for: 14b016ddb504bf5dcb9b7afcba30bff6
# Wrong start for: 14b016ddb504bf5dcb9b7afcba30bff6
# Wrong encoding for: 163a803032730143b17a5ee8a7d0bdab
# Wrong start for: 163a803032730143b17a5ee8a7d0bdab
# 7000
# Wrong encoding for: 194fe2423e78228a01a9e8e29ad6ae60
# Wrong start for: 194fe2423e78228a01a9e8e29ad6ae60
# 8000
# Wrong encoding for: 1db87b8c56ff656a3f9500475c7229db
# Wrong start for: 1db87b8c56ff656a3f9500475c7229db
# Wrong encoding for: 1ec6784d92cc8f50db431a9dd5c17aa4
# Wrong start for: 1ec6784d92cc8f50db431a9dd5c17aa4
# 9000
# 10000
# Wrong encoding for: 253b06da7475dea2f6ceb348dba4994f
# Wrong start for: 253b06da7475dea2f6ceb348dba4994f
# Wrong encoding for: 2549eb83cee8688bc83b65ef06753af9
# Wrong start for: 2549eb83cee8688bc83b65ef06753af9
# Wrong encoding for: 25c37403eec5fd4568635570456d5372
# Wrong start for: 25c37403eec5fd4568635570456d5372
# 11000
# Wrong encoding for: 261a861941620e128ca837c5e7eb7028
# Wrong start for: 261a861941620e128ca837c5e7eb7028
# 12000
# Wrong encoding for: 2ab428f99bc4f6c4c3635bc2d08339ad
# Wrong start for: 2ab428f99bc4f6c4c3635bc2d08339ad
# Wrong encoding for: 2b691077e54d6f5743a67ff8bd8b6a50
# Wrong start for: 2b691077e54d6f5743a67ff8bd8b6a50
# Wrong encoding for: 2e39b1a2d9768b806bdb1a14bdbc7f76
# Wrong start for: 2e39b1a2d9768b806bdb1a14bdbc7f76
# 13000
# 14000
# Wrong encoding for: 3449458f4341c42a4529be83069dd633
# Wrong start for: 3449458f4341c42a4529be83069dd633
# Wrong encoding for: 360cc3f8e039154bf15cd92d65d77862
# Wrong start for: 360cc3f8e039154bf15cd92d65d77862
# Wrong encoding for: 362c866bee48b41b57f3fa85e8f60106
# Wrong start for: 362c866bee48b41b57f3fa85e8f60106
# 15000
# 16000
# Wrong encoding for: 404c78be75ac114d3bb763e048663376
# Wrong start for: 404c78be75ac114d3bb763e048663376
# 17000
# Wrong encoding for: 4406b5f7ffdddea4452e4a2fe3c65fd0
# Wrong start for: 4406b5f7ffdddea4452e4a2fe3c65fd0
# 18000
# 19000
# Wrong encoding for: 49816c9f7bbf57e978b6cb6dcce8da1e
# Wrong start for: 49816c9f7bbf57e978b6cb6dcce8da1e
# 20000
# 21000
# Wrong encoding for: 515a54f48dd3d6367589198a369991ca
# Wrong start for: 515a54f48dd3d6367589198a369991ca
# 22000
# 23000
# 24000
# 25000
# Wrong encoding for: 5d8746134904a462b5c5993be60e267e
# Wrong start for: 5d8746134904a462b5c5993be60e267e
# 26000
# Wrong encoding for: 62684f5aa5ef2ed8d4723727704bbc62
# Wrong start for: 62684f5aa5ef2ed8d4723727704bbc62
# Wrong encoding for: 632be11ef924df71a3a23b879f86b241
# Wrong start for: 632be11ef924df71a3a23b879f86b241
# 27000
# Wrong encoding for: 635f2dd679ca2e4607f1d236001a5dca
# Wrong start for: 635f2dd679ca2e4607f1d236001a5dca
# Wrong encoding for: 657699e2873e406f688b5ceba110646d
# Wrong start for: 657699e2873e406f688b5ceba110646d
# 28000
# Wrong encoding for: 6aceaf6c5df93b2e08779a3466835b8a
# Wrong start for: 6aceaf6c5df93b2e08779a3466835b8a
# Wrong encoding for: 6b482b5612d12b9b9456a284fb926604
# Wrong start for: 6b482b5612d12b9b9456a284fb926604
# 29000
# Wrong encoding for: 6e27f540b3dc7df28c72ddcb8f3de7a2
# Wrong start for: 6e27f540b3dc7df28c72ddcb8f3de7a2
# 30000
# 31000
# 32000
# Wrong encoding for: 791c1c36a0ff34b46e40b6b09fd33702
# Wrong start for: 791c1c36a0ff34b46e40b6b09fd33702
# Wrong encoding for: 794c2d2cf07a21eb77fd2925dcfb9fbf
# Wrong start for: 794c2d2cf07a21eb77fd2925dcfb9fbf
# 33000
# Wrong encoding for: 797776ec447e42e7910707351ddc3c50
# Wrong start for: 797776ec447e42e7910707351ddc3c50
# Wrong encoding for: 7acff8aa078a263941386c1c9b5c270e
# Wrong start for: 7acff8aa078a263941386c1c9b5c270e
# 34000
# 35000
# Wrong encoding for: 83d10afadc19f374230e27a9283a5668
# Wrong start for: 83d10afadc19f374230e27a9283a5668
# 36000
# Wrong encoding for: 86ab3cb22c821992a1393022c3b79701
# Wrong start for: 86ab3cb22c821992a1393022c3b79701
# 37000
# 38000
# Wrong encoding for: 8d15b72f44cb93e25315617ce6fbc52c
# Wrong start for: 8d15b72f44cb93e25315617ce6fbc52c
# Wrong encoding for: 8df862228b08a4510db3cc0774680a9b
# Wrong start for: 8df862228b08a4510db3cc0774680a9b
# 39000
# Wrong encoding for: 9041f571afba4f140dfed9d07a13c462
# Wrong start for: 9041f571afba4f140dfed9d07a13c462
# 40000
# 41000
# Wrong encoding for: 9af122b3d01332af7d64acfa8a06656a
# Wrong start for: 9af122b3d01332af7d64acfa8a06656a
# Wrong encoding for: 9b6fb5847e97d0245b3bb9ccb91f5f75
# Wrong start for: 9b6fb5847e97d0245b3bb9ccb91f5f75
# Wrong encoding for: 9be4296cdea7cc65be869a990b13c0fb
# Wrong start for: 9be4296cdea7cc65be869a990b13c0fb
# 42000
# 43000
# Wrong encoding for: a1884c3bad9937db4890f7bbcb0bbe85
# Wrong start for: a1884c3bad9937db4890f7bbcb0bbe85
# 44000
# Wrong encoding for: a5f203c5e89e2049f69eae2b745ae39b
# Wrong start for: a5f203c5e89e2049f69eae2b745ae39b
# Wrong encoding for: a63005504c8b96b856c8dae00910301b
# Wrong start for: a63005504c8b96b856c8dae00910301b
# 45000
# 46000
# 47000
# Wrong encoding for: afe8421cf9f6db6a4ba821f39598a0a9
# Wrong start for: afe8421cf9f6db6a4ba821f39598a0a9
# 48000
# 49000
# Wrong encoding for: b630a364e6355a6d84e95bf213e893bf
# Wrong start for: b630a364e6355a6d84e95bf213e893bf
# 50000
# 51000
# Wrong encoding for: bd2c4187e9fb58282246a73fe05bf716
# Wrong start for: bd2c4187e9fb58282246a73fe05bf716
# Wrong encoding for: bec77fa62e5b7672a27e2a6c831ec1b0
# Wrong start for: bec77fa62e5b7672a27e2a6c831ec1b0
# 52000
# Wrong encoding for: c223b7d835fbcd17b271f22243c4a28b
# Wrong start for: c223b7d835fbcd17b271f22243c4a28b
# 53000
# Wrong encoding for: c66a6600ece1d0384ab0a42b358b63a9
# Wrong start for: c66a6600ece1d0384ab0a42b358b63a9
# 54000
# Wrong encoding for: c80b432eee90b4bb03f9ae842a2b78b0
# Wrong start for: c80b432eee90b4bb03f9ae842a2b78b0
# Wrong encoding for: c8e2192c745e14bb3bcdbefb35460772
# Wrong start for: c8e2192c745e14bb3bcdbefb35460772
# 55000
# 56000
# Wrong encoding for: cdfe2f564ce9c3b4d36c9f8a21a37774
# Wrong start for: cdfe2f564ce9c3b4d36c9f8a21a37774
# 57000
# 58000
# Wrong encoding for: d4c4fa6fc09b7853ddfb29cdb43bd981
# Wrong start for: d4c4fa6fc09b7853ddfb29cdb43bd981
# 59000
# Wrong encoding for: d5ac4cca97e8ea312dfb17c359c8978f
# Wrong start for: d5ac4cca97e8ea312dfb17c359c8978f
# Wrong encoding for: d6317a822970113539e9b4d81383dc25
# Wrong start for: d6317a822970113539e9b4d81383dc25
# 60000
# Wrong encoding for: db5ec311372509fc03918dd1aaef2cd3
# Wrong start for: db5ec311372509fc03918dd1aaef2cd3
# 61000
# Wrong encoding for: de28efdd081cc294ce1539198c07eb5e
# Wrong start for: de28efdd081cc294ce1539198c07eb5e
# Wrong encoding for: e15d83c0d63d1ef0c9d108ebeaaadcbc
# Wrong start for: e15d83c0d63d1ef0c9d108ebeaaadcbc
# Wrong encoding for: e1fda0a7658f1950c63f638194da744e
# Wrong start for: e1fda0a7658f1950c63f638194da744e
# Wrong encoding for: e2a5112aeaa0a952da48e653071196f0
# Wrong start for: e2a5112aeaa0a952da48e653071196f0
# 62000
# Wrong encoding for: e368ca0eb15f5ffcb816e8e3cd06ea1e
# Wrong start for: e368ca0eb15f5ffcb816e8e3cd06ea1e
# Wrong encoding for: e5965ec3de5fb70c54505faee8a132dc
# Wrong start for: e5965ec3de5fb70c54505faee8a132dc
# 63000
# Wrong encoding for: e839c137e59abb5d96bf8270b11ccfc2
# Wrong start for: e839c137e59abb5d96bf8270b11ccfc2
# Wrong encoding for: ea0b056b64ffb8f5d838b5a5014a3b33
# Wrong start for: ea0b056b64ffb8f5d838b5a5014a3b33
# Wrong encoding for: ea6fc882632b57fda9af67ac80c0878f
# Wrong start for: ea6fc882632b57fda9af67ac80c0878f
# 64000
# Wrong encoding for: eb27a64e7308d6736bdb1c89338dcf4c
# Wrong start for: eb27a64e7308d6736bdb1c89338dcf4c
