# %%
# needed imports
import numpy as np
import os
import cv2
from cv2 import connectedComponents

# plotting images
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
from skimage.morphology import binary_closing, closing, opening
from skimage.morphology import square
from scipy.misc import imresize

# %%
class_labels = np.array((33, 34, 35, 36, 38, 39, 40, 0))

# %%
directory = './data/full_data/predictions'

filelist = np.array(sorted(os.listdir(directory)))

for file in filelist[:5]:
